# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder
from sklearn.compose import make_column_transformer
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
from sklearn import set_config
set_config(transform_output='pandas')

# %%
data_final = pd.read_csv("houses_full.csv")

# %% [markdown]
# # Analysis

# %% [markdown]
# ## Columns

# %% [markdown]
# Need to look at the columns which couldn't be expressed with Numbers

# %%
data_final = data_final.set_index("Id")

# %%
data_final.isna().sum()
# Out:
# LotArea             0
# LotFrontage       259
# TotalBsmtSF         0
# BedroomAbvGr        0
# Fireplaces          0
#                  ...
# PoolQC           1453
# Fence            1179
# MiscFeature      1406
# SaleType            0
# SaleCondition       0
# Length: 80, dtype: int64

# %% [markdown]
# See if there any redundant Columns through their NaN values

# %%
data_final.isna().sum().sort_values(ascending=False)/len(data_final)*100
# Out:
# PoolQC           99.520548
# MiscFeature      96.301370
# Alley            93.767123
# Fence            80.753425
# MasVnrType       59.726027
#                    ...
# HeatingQC         0.000000
# Functional        0.000000
# PavedDrive        0.000000
# SaleType          0.000000
# SaleCondition     0.000000
# Length: 80, dtype: float64

# %%
data_final.loc[data_final["Fence"].isna(), "Fence"] = "No Fence"

# %%
data_final["LotFrontage"].isna().sum()
# Out:
# np.int64(259)

# %%
# X and y creation
x = data_final.drop(columns=["PoolQC", "MiscFeature", "Alley", "FireplaceQu", "RoofMatl", "Exterior1st", 
                             "Exterior2nd", "SaleType", "SaleCondition", "Utilities"])
y = x.pop("Expensive")

# %%
x.loc[x["Street"] == "Pave", "Street"] = 1
x.loc[x["Street"] == "Grvl", "Street"] = 0

x.loc[x["CentralAir"] == "Y", "CentralAir"] = 1
x.loc[x["CentralAir"] == "N", "CentralAir"] = 0

# %%
x.isna().sum().sort_values(ascending=False)/len(data_final)*100
# Out:
# MasVnrType     59.726027
# LotFrontage    17.739726
# GarageCond      5.547945
# GarageType      5.547945
# GarageQual      5.547945
#                  ...
# HouseStyle      0.000000
# Condition2      0.000000
# Functional      0.000000
# PavedDrive      0.000000
# Fence           0.000000
# Length: 69, dtype: float64

# %%
cat_features = x.select_dtypes(exclude="number").columns
cat_features
# Out:
# Index(['MSZoning', 'Condition1', 'Heating', 'Street', 'CentralAir',
#        'Foundation', 'ExterQual', 'ExterCond', 'BsmtQual', 'BsmtCond',
#        'BsmtExposure', 'BsmtFinType1', 'KitchenQual', 'LotShape',
#        'LandContour', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition2',
#        'BldgType', 'HouseStyle', 'RoofStyle', 'MasVnrType', 'BsmtFinType2',
#        'HeatingQC', 'Electrical', 'Functional', 'GarageType', 'GarageFinish',
#        'GarageQual', 'GarageCond', 'PavedDrive', 'Fence'],
#       dtype='object')

# %% [markdown]
# ## Preprocessor

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=42, stratify=y)

print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (1168, 69)
# (292, 69)
# (1168,)
# (292,)

# %%
import numpy as np
from sklearn.impute import KNNImputer
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler

# %%
knn_imputer = KNNImputer(n_neighbors=2)
minmax = MinMaxScaler()
standard = StandardScaler()

num_pipe = make_pipeline(knn_imputer, minmax)

num_feat = x_train.select_dtypes(include=['int64', 'float64']).columns

make_column_transformer(num_pipe, num_feat)
# Out:
# ColumnTransformer(transformers=[('knnimputer', KNNImputer(n_neighbors=2),
#                                  MinMaxScaler()),
#                                 ('LotArea', 'LotArea', 'LotFrontage')])

# %%
ordinal_imputer = SimpleImputer(strategy='constant', fill_value='missing')

feat_ordinal_dict = {
    # Considers "missing" as worse than poor=does not have effect
    "BsmtCond": ['missing', 'Po', 'Fa', 'TA', 'Gd'], #-> 0, 1, 2, 3, 4
    #otherwise OrdinalEncoder gives values based on order of appearance
    "BsmtExposure": ['missing', 'No', 'Mn', 'Av', 'Gd'],
    "ExterQual": ['missing', 'Po', 'Fa', 'TA', 'Gd', "Ex"],
    "ExterCond": ['missing', 'Po', 'Fa', 'TA', 'Gd', "Ex"],
    "BsmtQual": ['missing', 'Po', 'Fa', 'TA', 'Gd', "Ex"],
    "BsmtFinType1": ['missing', 'Unf', 'LwQ', 'Rec', 'BLQ', "ALQ", "GLQ"],
    "BsmtFinType2": ['missing', 'Unf', 'LwQ', 'Rec', 'BLQ', "ALQ", "GLQ"],
    "KitchenQual": ['missing', 'Po', 'Fa', 'TA', 'Gd', "Ex"],
    "LotShape": ["missing", "IR3", "IR2", "IR1", "Reg"],
    "HeatingQC": ["missing", "Po", "Fa", "TA", "Gd", "Ex"],
    "Fence": ["missing", "MnWw", "GdWo", "MnPrv", "GdPrv"],
    "Functional": ['missing', 'Sal', 'Sev', 'Maj2', 'Maj1', "Mod", "Min2", "Min1", "Typ"],
    "GarageFinish": ["missing", "Unf", "RFn", "Fin"],
    "GarageQual": ["missing", "Po", "Fa", "TA", "Gd", "Ex"],
    "GarageCond": ["missing", "Po", "Fa", "TA", "Gd", "Ex"]
    }

feat_ordinal = sorted(feat_ordinal_dict.keys())
feat_ordinal_values = [feat_ordinal_dict[i] for i in feat_ordinal]

ord_encoder = OrdinalEncoder(categories=feat_ordinal_values,
                             dtype= np.int64,
                             handle_unknown="use_encoded_value",
                             unknown_value=-1
                             )

ordinal_pipe = make_pipeline(ordinal_imputer, ord_encoder)

make_column_transformer((ordinal_pipe, feat_ordinal))
# Out:
# ColumnTransformer(transformers=[('pipeline',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer(fill_value='missing',
#                                                                 strategy='constant')),
#                                                  ('ordinalencoder',
#                                                   OrdinalEncoder(categories=[['missing',
#                                                                               'Po',
#                                                                               'Fa',
#                                                                               'TA',
#                                                                               'Gd'],
#                                                                              ['missing',
#                                                                               'No',
#                                                                               'Mn',
#                                                                               'Av',
#                                                                               'Gd'],
#                                                                              ['missing',
#                                                                               'Unf',
#                                                                               'LwQ',
#                                                                               'Rec',
#                                                                               'BLQ',
#                                                                               'ALQ',
#                                                                               'GLQ'],
#                                                                              ['missing',
#                                                                               'Unf',
#                                                                               'LwQ',
#                                                                               'Rec',
#                                                                               'BLQ',
#                                                                               'ALQ',
#                                                                               'GLQ'],
#                                                                              ['missing',...
#                                                                              ['missing',
#                                                                               'Po',
#                                                                               'Fa',
#                                                                               'TA',
#                                                                               'Gd',
#                                                                               'Ex'],
#                                                                              ['missing',
#                                                                               'IR3',
#                                                                               'IR2',
#                                                                               'IR1',
#                                                                               'Reg']],
#                                                                  dtype=<class 'numpy.int64'>,
#                                                                  handle_unknown='use_encoded_value',
#                                                                  unknown_value=-1))]),
#                                  ['BsmtCond', 'BsmtExposure', 'BsmtFinType1',
#                                   'BsmtFinType2', 'BsmtQual', 'ExterCond',
#                                   'ExterQual', 'Fence', 'Functional',
#                                   'GarageCond', 'GarageFinish', 'GarageQual',
#                                   'HeatingQC', 'KitchenQual', 'LotShape'])])

# %%
make_column_transformer((ordinal_pipe, feat_ordinal),
                        (num_pipe, num_feat))
# Out:
# ColumnTransformer(transformers=[('pipeline-1',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer(fill_value='missing',
#                                                                 strategy='constant')),
#                                                  ('ordinalencoder',
#                                                   OrdinalEncoder(categories=[['missing',
#                                                                               'Po',
#                                                                               'Fa',
#                                                                               'TA',
#                                                                               'Gd'],
#                                                                              ['missing',
#                                                                               'No',
#                                                                               'Mn',
#                                                                               'Av',
#                                                                               'Gd'],
#                                                                              ['missing',
#                                                                               'Unf',
#                                                                               'LwQ',
#                                                                               'Rec',
#                                                                               'BLQ',
#                                                                               'ALQ',
#                                                                               'GLQ'],
#                                                                              ['missing',
#                                                                               'Unf',
#                                                                               'LwQ',
#                                                                               'Rec',
#                                                                               'BLQ',
#                                                                               'ALQ',
#                                                                               'GLQ'],
#                                                                              ['missing...
#        'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea',
#        'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'KitchenAbvGr', 'TotRmsAbvGrd', 'GarageYrBlt', 'GarageArea',
#        'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'MiscVal', 'MoSold',
#        'YrSold'],
#       dtype='object'))])

# %%
ohe_imputer = SimpleImputer(strategy='most_frequent')

ohe = OneHotEncoder(sparse_output=False, handle_unknown='ignore')

ohe_pipe = make_pipeline(ohe_imputer, ohe)

ohe_feat = list(set(x_train.columns) - set(num_feat) - set(feat_ordinal))

make_column_transformer((ohe_pipe, ohe_feat))
# Out:
# ColumnTransformer(transformers=[('pipeline',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer(strategy='most_frequent')),
#                                                  ('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse_output=False))]),
#                                  ['MSZoning', 'BldgType', 'LandContour',
#                                   'Street', 'CentralAir', 'Neighborhood',
#                                   'LotConfig', 'HouseStyle', 'LandSlope',
#                                   'GarageType', 'PavedDrive', 'Condition1',
#                                   'Electrical', 'MasVnrType', 'RoofStyle',
#                                   'Heating', 'Condition2', 'Foundation'])])

# %%
list1 = list(num_feat)

# %%
preproc_pipeline = make_column_transformer(( num_pipe, list1), #num pipe
    (ordinal_pipe , feat_ordinal), #Ordinal pipe
    (ohe_pipe, ohe_feat) #ohe pipe
    )
preproc_pipeline
# Out:
# ColumnTransformer(transformers=[('pipeline-1',
#                                  Pipeline(steps=[('knnimputer',
#                                                   KNNImputer(n_neighbors=2)),
#                                                  ('minmaxscaler',
#                                                   MinMaxScaler())]),
#                                  ['LotArea', 'LotFrontage', 'TotalBsmtSF',
#                                   'BedroomAbvGr', 'Fireplaces', 'PoolArea',
#                                   'GarageCars', 'WoodDeckSF', 'ScreenPorch',
#                                   'MSSubClass', 'OverallQual', 'OverallCond',
#                                   'YearBuilt', 'YearRemodAdd', 'MasVnrArea',
#                                   'BsmtFinSF1', '...
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer(strategy='most_frequent')),
#                                                  ('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse_output=False))]),
#                                  ['MSZoning', 'BldgType', 'LandContour',
#                                   'Street', 'CentralAir', 'Neighborhood',
#                                   'LotConfig', 'HouseStyle', 'LandSlope',
#                                   'GarageType', 'PavedDrive', 'Condition1',
#                                   'Electrical', 'MasVnrType', 'RoofStyle',
#                                   'Heating', 'Condition2', 'Foundation'])])

# %%
preproc_pipeline.fit_transform(x_train, y_train)
# Out:
#       pipeline-1__LotArea  pipeline-1__LotFrontage  pipeline-1__TotalBsmtSF  \
# Id
# 1212             0.050639                 0.448630                 0.091489
# 554              0.034948                 0.157534                 0.000000
# 1194             0.014957                 0.042808                 0.200327
# 303              0.057978                 0.332192                 0.252209
# 1069             0.012452                 0.071918                 0.154173
# ...                   ...                      ...                      ...
# 471              0.025801                 0.183219                 0.243535
# 808              0.093875                 0.421233                 0.216694
# 547              0.034761                 0.167808                 0.174304
# 8                0.042450                 0.239726                 0.181178
# 1226             0.042918                 0.150685                 0.096236
#
#       pipeline-1__BedroomAbvGr  pipeline-1__Fireplaces  pipeline-1__PoolArea  \
# Id
# 1212                     0.500                0.000000                   0.0
# 554                      0.250                0.000000                   0.0
# 1194                     0.250                0.000000                   0.0
# 303                      0.375                0.333333                   0.0
# 1069                     0.625                0.333333                   0.0
# ...                        ...                     ...                   ...
# 471                      0.125                0.000000                   0.0
# 808                      0.375                0.333333                   0.0
# 547                      0.375                0.333333                   0.0
# 8                        0.375                0.666667                   0.0
# 1226                     0.375                0.000000                   0.0
#
#       pipeline-1__GarageCars  pipeline-1__WoodDeckSF  pipeline-1__ScreenPorch  \
# Id
# 1212                    0.50                0.379230                 0.000000
# 554                     0.50                0.000000                 0.000000
# 1194                    0.50                0.000000                 0.000000
# 303                     0.75                0.546091                 0.000000
# 1069                    0.50                0.849475                 0.000000
# ...                      ...                     ...                      ...
# 471                     0.50                0.000000                 0.291667
# 808                     0.50                0.000000                 0.000000
# 547                     0.50                0.000000                 0.000000
# 8                       0.50                0.274212                 0.000000
# 1226                    0.25                0.261377                 0.000000
#
#       pipeline-1__MSSubClass  ...  pipeline-3__Condition2_PosN  \
# Id                            ...
# 1212                0.176471  ...                          0.0
# 554                 0.000000  ...                          0.0
# 1194                0.588235  ...                          0.0
# 303                 0.000000  ...                          0.0
# 1069                0.823529  ...                          0.0
# ...                      ...  ...                          ...
# 471                 0.588235  ...                          0.0
# 808                 0.294118  ...                          0.0
# 547                 0.176471  ...                          0.0
# 8                   0.235294  ...                          0.0
# 1226                0.352941  ...                          0.0
#
#       pipeline-3__Condition2_RRAe  pipeline-3__Condition2_RRAn  \
# Id
# 1212                          0.0                          0.0
# 554                           0.0                          0.0
# 1194                          0.0                          0.0
# 303                           0.0                          0.0
# 1069                          0.0                          0.0
# ...                           ...                          ...
# 471                           0.0                          0.0
# 808                           0.0                          0.0
# 547                           0.0                          0.0
# 8                             0.0                          0.0
# 1226                          0.0                          0.0
#
#       pipeline-3__Condition2_RRNn  pipeline-3__Foundation_BrkTil  \
# Id
# 1212                          0.0                            0.0
# 554                           0.0                            0.0
# 1194                          0.0                            0.0
# 303                           0.0                            0.0
# 1069                          0.0                            0.0
# ...                           ...                            ...
# 471                           0.0                            0.0
# 808                           0.0                            0.0
# 547                           0.0                            1.0
# 8                             0.0                            0.0
# 1226                          0.0                            0.0
#
#       pipeline-3__Foundation_CBlock  pipeline-3__Foundation_PConc  \
# Id
# 1212                            0.0                           0.0
# 554                             1.0                           0.0
# 1194                            0.0                           1.0
# 303                             0.0                           1.0
# 1069                            1.0                           0.0
# ...                             ...                           ...
# 471                             0.0                           1.0
# 808                             1.0                           0.0
# 547                             0.0                           0.0
# 8                               1.0                           0.0
# 1226                            1.0                           0.0
#
#       pipeline-3__Foundation_Slab  pipeline-3__Foundation_Stone  \
# Id
# 1212                          0.0                           0.0
# 554                           0.0                           0.0
# 1194                          0.0                           0.0
# 303                           0.0                           0.0
# 1069                          0.0                           0.0
# ...                           ...                           ...
# 471                           0.0                           0.0
# 808                           0.0                           0.0
# 547                           0.0                           0.0
# 8                             0.0                           0.0
# 1226                          0.0                           0.0
#
#       pipeline-3__Foundation_Wood
# Id
# 1212                          1.0
# 554                           0.0
# 1194                          0.0
# 303                           0.0
# 1069                          0.0
# ...                           ...
# 471                           0.0
# 808                           0.0
# 547                           0.0
# 8                             0.0
# 1226                          0.0
#
# [1168 rows x 161 columns]

# %%
preproc_pipeline.get_params()
# Out:
# {'force_int_remainder_cols': 'deprecated',
#  'n_jobs': None,
#  'remainder': 'drop',
#  'sparse_threshold': 0.3,
#  'transformer_weights': None,
#  'transformers': [('pipeline-1',
#    Pipeline(steps=[('knnimputer', KNNImputer(n_neighbors=2)),
#                    ('minmaxscaler', MinMaxScaler())]),
#    ['LotArea',
#     'LotFrontage',
#     'TotalBsmtSF',
#     'BedroomAbvGr',
#     'Fireplaces',
#     'PoolArea',
#     'GarageCars',
#     'WoodDeckSF',
#     'ScreenPorch',
#     'MSSubClass',
#     'OverallQual',
#     'OverallCond',
#     'YearBuilt',
#     'YearRemodAdd',
#     'MasVnrArea',
#     'BsmtFinSF1',
#     'BsmtFinSF2',
#     'BsmtUnfSF',
#     '1stFlrSF',
#     '2ndFlrSF',
#     'LowQualFinSF',
#     'GrLivArea',
#     'BsmtFullBath',
#     'BsmtHalfBath',
#     'FullBath',
#     'HalfBath',
#     'KitchenAbvGr',
#     'TotRmsAbvGrd',
#     'GarageYrBlt',
#     'GarageArea',
#     'OpenPorchSF',
#     'EnclosedPorch',
#     '3SsnPorch',
#     'MiscVal',
#     'MoSold',
#     'YrSold']),
#   ('pipeline-2',
#    Pipeline(steps=[('simpleimputer',
#                     SimpleImputer(fill_value='missing', strategy='constant')),
#                    ('ordinalencoder',
#                     OrdinalEncoder(categories=[['missing', 'Po', 'Fa', 'TA', 'Gd'],
#                                                ['missing', 'No', 'Mn', 'Av', 'Gd'],
#                                                ['missing', 'Unf', 'LwQ', 'Rec',
#                                                 'BLQ', 'ALQ', 'GLQ'],
#                                                ['missing', 'Unf', 'LwQ', 'Rec',
#                                                 'BLQ', 'ALQ', 'GLQ'],
#                                                ['missing', 'Po', 'Fa', 'TA', 'Gd',
#                                                 'Ex'],
#                                                ['missing', 'Po', 'F...
#                                                ['missing', 'Sal', 'Sev', 'Maj2',
#                                                 'Maj1', 'Mod', 'Min2', 'Min1',
#                                                 'Typ'],
#                                                ['missing', 'Po', 'Fa', 'TA', 'Gd',
#                                                 'Ex'],
#                                                ['missing', 'Unf', 'RFn', 'Fin'],
#                                                ['missing', 'Po', 'Fa', 'TA', 'Gd',
#                                                 'Ex'],
#                                                ['missing', 'Po', 'Fa', 'TA', 'Gd',
#                                                 'Ex'],
#                                                ['missing', 'Po', 'Fa', 'TA', 'Gd',
#                                                 'Ex'],
#                                                ['missing', 'IR3', 'IR2', 'IR1',
#                                                 'Reg']],
#                                    dtype=<class 'numpy.int64'>,
#                                    handle_unknown='use_encoded_value',
#                                    unknown_value=-1))]),
#    ['BsmtCond',
#     'BsmtExposure',
#     'BsmtFinType1',
#     'BsmtFinType2',
#     'BsmtQual',
#     'ExterCond',
#     'ExterQual',
#     'Fence',
#     'Functional',
#     'GarageCond',
#     'GarageFinish',
#     'GarageQual',
#     'HeatingQC',
#     'KitchenQual',
#     'LotShape']),
#   ('pipeline-3',
#    Pipeline(steps=[('simpleimputer', SimpleImputer(strategy='most_frequent')),
#                    ('onehotencoder',
#                     OneHotEncoder(handle_unknown='ignore', sparse_output=False))]),
#    ['MSZoning',
#     'BldgType',
#     'LandContour',
#     'Street',
#     'CentralAir',
#     'Neighborhood',
#     'LotConfig',
#     'HouseStyle',
#     'LandSlope',
#     'GarageType',
#     'PavedDrive',
#     'Condition1',
#     'Electrical',
#     'MasVnrType',
#     'RoofStyle',
#     'Heating',
#     'Condition2',
#     'Foundation'])],
#  'verbose': False,
#  'verbose_feature_names_out': True,
#  'pipeline-1': Pipeline(steps=[('knnimputer', KNNImputer(n_neighbors=2)),
#                  ('minmaxscaler', MinMaxScaler())]),
#  'pipeline-2': Pipeline(steps=[('simpleimputer',
#                   SimpleImputer(fill_value='missing', strategy='constant')),
#                  ('ordinalencoder',
#                   OrdinalEncoder(categories=[['missing', 'Po', 'Fa', 'TA', 'Gd'],
#                                              ['missing', 'No', 'Mn', 'Av', 'Gd'],
#                                              ['missing', 'Unf', 'LwQ', 'Rec',
#                                               'BLQ', 'ALQ', 'GLQ'],
#                                              ['missing', 'Unf', 'LwQ', 'Rec',
#                                               'BLQ', 'ALQ', 'GLQ'],
#                                              ['missing', 'Po', 'Fa', 'TA', 'Gd',
#                                               'Ex'],
#                                              ['missing', 'Po', 'F...
#                                              ['missing', 'Sal', 'Sev', 'Maj2',
#                                               'Maj1', 'Mod', 'Min2', 'Min1',
#                                               'Typ'],
#                                              ['missing', 'Po', 'Fa', 'TA', 'Gd',
#                                               'Ex'],
#                                              ['missing', 'Unf', 'RFn', 'Fin'],
#                                              ['missing', 'Po', 'Fa', 'TA', 'Gd',
#                                               'Ex'],
#                                              ['missing', 'Po', 'Fa', 'TA', 'Gd',
#                                               'Ex'],
#                                              ['missing', 'Po', 'Fa', 'TA', 'Gd',
#                                               'Ex'],
#                                              ['missing', 'IR3', 'IR2', 'IR1',
#                                               'Reg']],
#                                  dtype=<class 'numpy.int64'>,
#                                  handle_unknown='use_encoded_value',
#                                  unknown_value=-1))]),
#  'pipeline-3': Pipeline(steps=[('simpleimputer', SimpleImputer(strategy='most_frequent')),
#                  ('onehotencoder',
#                   OneHotEncoder(handle_unknown='ignore', sparse_output=False))]),
#  'pipeline-1__memory': None,
#  'pipeline-1__steps': [('knnimputer', KNNImputer(n_neighbors=2)),
#   ('minmaxscaler', MinMaxScaler())],
#  'pipeline-1__transform_input': None,
#  'pipeline-1__verbose': False,
#  'pipeline-1__knnimputer': KNNImputer(n_neighbors=2),
#  'pipeline-1__minmaxscaler': MinMaxScaler(),
#  'pipeline-1__knnimputer__add_indicator': False,
#  'pipeline-1__knnimputer__copy': True,
#  'pipeline-1__knnimputer__keep_empty_features': False,
#  'pipeline-1__knnimputer__metric': 'nan_euclidean',
#  'pipeline-1__knnimputer__missing_values': nan,
#  'pipeline-1__knnimputer__n_neighbors': 2,
#  'pipeline-1__knnimputer__weights': 'uniform',
#  'pipeline-1__minmaxscaler__clip': False,
#  'pipeline-1__minmaxscaler__copy': True,
#  'pipeline-1__minmaxscaler__feature_range': (0, 1),
#  'pipeline-2__memory': None,
#  'pipeline-2__steps': [('simpleimputer',
#    SimpleImputer(fill_value='missing', strategy='constant')),
#   ('ordinalencoder',
#    OrdinalEncoder(categories=[['missing', 'Po', 'Fa', 'TA', 'Gd'],
#                               ['missing', 'No', 'Mn', 'Av', 'Gd'],
#                               ['missing', 'Unf', 'LwQ', 'Rec', 'BLQ', 'ALQ',
#                                'GLQ'],
#                               ['missing', 'Unf', 'LwQ', 'Rec', 'BLQ', 'ALQ',
#                                'GLQ'],
#                               ['missing', 'Po', 'Fa', 'TA', 'Gd', 'Ex'],
#                               ['missing', 'Po', 'Fa', 'TA', 'Gd', 'Ex'],
#                               ['missing', 'Po', 'Fa', 'TA', 'Gd', 'Ex'],
#                               ['missing', 'MnWw', 'GdWo', 'MnPrv', 'GdPrv'],
#                               ['missing', 'Sal', 'Sev', 'Maj2', 'Maj1', 'Mod',
#                                'Min2', 'Min1', 'Typ'],
#                               ['missing', 'Po', 'Fa', 'TA', 'Gd', 'Ex'],
#                               ['missing', 'Unf', 'RFn', 'Fin'],
#                               ['missing', 'Po', 'Fa', 'TA', 'Gd', 'Ex'],
#                               ['missing', 'Po', 'Fa', 'TA', 'Gd', 'Ex'],
#                               ['missing', 'Po', 'Fa', 'TA', 'Gd', 'Ex'],
#                               ['missing', 'IR3', 'IR2', 'IR1', 'Reg']],
#                   dtype=<class 'numpy.int64'>, handle_unknown='use_encoded_value',
#                   unknown_value=-1))],
#  'pipeline-2__transform_input': None,
#  'pipeline-2__verbose': False,
#  'pipeline-2__simpleimputer': SimpleImputer(fill_value='missing', strategy='constant'),
#  'pipeline-2__ordinalencoder': OrdinalEncoder(categories=[['missing', 'Po', 'Fa', 'TA', 'Gd'],
#                             ['missing', 'No', 'Mn', 'Av', 'Gd'],
#                             ['missing', 'Unf', 'LwQ', 'Rec', 'BLQ', 'ALQ',
#                              'GLQ'],
#                             ['missing', 'Unf', 'LwQ', 'Rec', 'BLQ', 'ALQ',
#                              'GLQ'],
#                             ['missing', 'Po', 'Fa', 'TA', 'Gd', 'Ex'],
#                             ['missing', 'Po', 'Fa', 'TA', 'Gd', 'Ex'],
#                             ['missing', 'Po', 'Fa', 'TA', 'Gd', 'Ex'],
#                             ['missing', 'MnWw', 'GdWo', 'MnPrv', 'GdPrv'],
#                             ['missing', 'Sal', 'Sev', 'Maj2', 'Maj1', 'Mod',
#                              'Min2', 'Min1', 'Typ'],
#                             ['missing', 'Po', 'Fa', 'TA', 'Gd', 'Ex'],
#                             ['missing', 'Unf', 'RFn', 'Fin'],
#                             ['missing', 'Po', 'Fa', 'TA', 'Gd', 'Ex'],
#                             ['missing', 'Po', 'Fa', 'TA', 'Gd', 'Ex'],
#                             ['missing', 'Po', 'Fa', 'TA', 'Gd', 'Ex'],
#                             ['missing', 'IR3', 'IR2', 'IR1', 'Reg']],
#                 dtype=<class 'numpy.int64'>, handle_unknown='use_encoded_value',
#                 unknown_value=-1),
#  'pipeline-2__simpleimputer__add_indicator': False,
#  'pipeline-2__simpleimputer__copy': True,
#  'pipeline-2__simpleimputer__fill_value': 'missing',
#  'pipeline-2__simpleimputer__keep_empty_features': False,
#  'pipeline-2__simpleimputer__missing_values': nan,
#  'pipeline-2__simpleimputer__strategy': 'constant',
#  'pipeline-2__ordinalencoder__categories': [['missing',
#    'Po',
#    'Fa',
#    'TA',
#    'Gd'],
#   ['missing', 'No', 'Mn', 'Av', 'Gd'],
#   ['missing', 'Unf', 'LwQ', 'Rec', 'BLQ', 'ALQ', 'GLQ'],
#   ['missing', 'Unf', 'LwQ', 'Rec', 'BLQ', 'ALQ', 'GLQ'],
#   ['missing', 'Po', 'Fa', 'TA', 'Gd', 'Ex'],
#   ['missing', 'Po', 'Fa', 'TA', 'Gd', 'Ex'],
#   ['missing', 'Po', 'Fa', 'TA', 'Gd', 'Ex'],
#   ['missing', 'MnWw', 'GdWo', 'MnPrv', 'GdPrv'],
#   ['missing', 'Sal', 'Sev', 'Maj2', 'Maj1', 'Mod', 'Min2', 'Min1', 'Typ'],
#   ['missing', 'Po', 'Fa', 'TA', 'Gd', 'Ex'],
#   ['missing', 'Unf', 'RFn', 'Fin'],
#   ['missing', 'Po', 'Fa', 'TA', 'Gd', 'Ex'],
#   ['missing', 'Po', 'Fa', 'TA', 'Gd', 'Ex'],
#   ['missing', 'Po', 'Fa', 'TA', 'Gd', 'Ex'],
#   ['missing', 'IR3', 'IR2', 'IR1', 'Reg']],
#  'pipeline-2__ordinalencoder__dtype': numpy.int64,
#  'pipeline-2__ordinalencoder__encoded_missing_value': nan,
#  'pipeline-2__ordinalencoder__handle_unknown': 'use_encoded_value',
#  'pipeline-2__ordinalencoder__max_categories': None,
#  'pipeline-2__ordinalencoder__min_frequency': None,
#  'pipeline-2__ordinalencoder__unknown_value': -1,
#  'pipeline-3__memory': None,
#  'pipeline-3__steps': [('simpleimputer',
#    SimpleImputer(strategy='most_frequent')),
#   ('onehotencoder',
#    OneHotEncoder(handle_unknown='ignore', sparse_output=False))],
#  'pipeline-3__transform_input': None,
#  'pipeline-3__verbose': False,
#  'pipeline-3__simpleimputer': SimpleImputer(strategy='most_frequent'),
#  'pipeline-3__onehotencoder': OneHotEncoder(handle_unknown='ignore', sparse_output=False),
#  'pipeline-3__simpleimputer__add_indicator': False,
#  'pipeline-3__simpleimputer__copy': True,
#  'pipeline-3__simpleimputer__fill_value': None,
#  'pipeline-3__simpleimputer__keep_empty_features': False,
#  'pipeline-3__simpleimputer__missing_values': nan,
#  'pipeline-3__simpleimputer__strategy': 'most_frequent',
#  'pipeline-3__onehotencoder__categories': 'auto',
#  'pipeline-3__onehotencoder__drop': None,
#  'pipeline-3__onehotencoder__dtype': numpy.float64,
#  'pipeline-3__onehotencoder__feature_name_combiner': 'concat',
#  'pipeline-3__onehotencoder__handle_unknown': 'ignore',
#  'pipeline-3__onehotencoder__max_categories': None,
#  'pipeline-3__onehotencoder__min_frequency': None,
#  'pipeline-3__onehotencoder__sparse_output': False}

# %% [markdown]
# ## DecisionTree/DecisionForest

# %%
forest = RandomForestClassifier()

# %%
forest.estimator_params
# Out:
# ('criterion',
#  'max_depth',
#  'min_samples_split',
#  'min_samples_leaf',
#  'min_weight_fraction_leaf',
#  'max_features',
#  'max_leaf_nodes',
#  'min_impurity_decrease',
#  'random_state',
#  'ccp_alpha',
#  'monotonic_cst')

# %%
tree = DecisionTreeClassifier(max_depth = 6, 
                              min_samples_leaf = 3)

forest = RandomForestClassifier(min_samples_leaf=2,
                                min_samples_split=9,
                                random_state=123)

pipe = make_pipeline(preproc_pipeline, forest)

pipe.fit(x_train, y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('pipeline-1',
#                                                   Pipeline(steps=[('knnimputer',
#                                                                    KNNImputer(n_neighbors=2)),
#                                                                   ('minmaxscaler',
#                                                                    MinMaxScaler())]),
#                                                   ['LotArea', 'LotFrontage',
#                                                    'TotalBsmtSF',
#                                                    'BedroomAbvGr', 'Fireplaces',
#                                                    'PoolArea', 'GarageCars',
#                                                    'WoodDeckSF', 'ScreenPorch',
#                                                    'MSSubClass', 'OverallQual',
#                                                    'OverallCond', 'YearBuilt',
#                                                    'Year...
#                                                                                  sparse_output=False))]),
#                                                   ['MSZoning', 'BldgType',
#                                                    'LandContour', 'Street',
#                                                    'CentralAir', 'Neighborhood',
#                                                    'LotConfig', 'HouseStyle',
#                                                    'LandSlope', 'GarageType',
#                                                    'PavedDrive', 'Condition1',
#                                                    'Electrical', 'MasVnrType',
#                                                    'RoofStyle', 'Heating',
#                                                    'Condition2',
#                                                    'Foundation'])])),
#                 ('randomforestclassifier',
#                  RandomForestClassifier(min_samples_leaf=2, min_samples_split=9,
#                                         random_state=123))])

# %% [markdown]
# ## GridSearchCV

# %%
x_train
# Out:
#       LotArea  LotFrontage  TotalBsmtSF  BedroomAbvGr  Fireplaces  PoolArea  \
# Id
# 1212    12134        152.0          559             4           0         0
# 554      8777         67.0            0             2           0         0
# 1194     4500          NaN         1224             2           0         0
# 303     13704        118.0         1541             3           1         0
# 1069     3964         42.0          942             5           1         0
# ...       ...          ...          ...           ...         ...       ...
# 471      6820          NaN         1488             1           0         0
# 808     21384        144.0         1324             3           1         0
# 547      8737         70.0         1065             3           1         0
# 8       10382          NaN         1107             3           2         0
# 1226    10482         65.0          588             3           0         0
#
#       GarageCars  WoodDeckSF  ScreenPorch MSZoning  ... BsmtFinType2  \
# Id                                                  ...
# 1212           2         325            0       RL  ...          Unf
# 554            2           0            0       RL  ...          NaN
# 1194           2           0            0       RM  ...          Unf
# 303            3         468            0       RL  ...          Unf
# 1069           2         728            0       RM  ...          Unf
# ...          ...         ...          ...      ...  ...          ...
# 471            2           0          140       RL  ...          BLQ
# 808            2           0            0       RL  ...          Unf
# 547            2           0            0       RL  ...          Unf
# 8              2         235            0       RL  ...          BLQ
# 1226           1         224            0       RL  ...          Unf
#
#      HeatingQC Electrical Functional GarageType GarageFinish GarageQual  \
# Id
# 1212        Gd      SBrkr        Typ    Basment          RFn         TA
# 554         Ex      SBrkr        Typ     Detchd          Fin         TA
# 1194        Ex      SBrkr        Typ     Attchd          Fin         TA
# 303         Ex      SBrkr        Typ     Attchd          RFn         TA
# 1069        Gd      SBrkr       Maj1     Attchd          Fin         TA
# ...        ...        ...        ...        ...          ...        ...
# 471         TA      SBrkr        Typ     Attchd          RFn         TA
# 808         Ex      SBrkr        Typ     Attchd          RFn         TA
# 547         Ex      FuseA        Typ     Detchd          Unf         TA
# 8           Ex      SBrkr        Typ     Attchd          RFn         TA
# 1226        Ex      SBrkr        Typ     Attchd          RFn         TA
#
#      GarageCond PavedDrive     Fence
# Id
# 1212         TA          Y  No Fence
# 554          TA          N     MnPrv
# 1194         TA          Y  No Fence
# 303          TA          Y  No Fence
# 1069         TA          Y     GdPrv
# ...         ...        ...       ...
# 471          TA          Y  No Fence
# 808          TA          Y  No Fence
# 547          TA          Y  No Fence
# 8            TA          Y  No Fence
# 1226         TA          Y      MnWw
#
# [1168 rows x 69 columns]

# %%
# Define a dictionary of hyperparameters to tune for the decision tree model
param_grid = {
    "randomforestclassifier__min_samples_leaf": range(2, 14, 2),
    "randomforestclassifier__min_samples_split": range(3, 12, 2)
}

# %%
search = GridSearchCV(pipe, # you have defined this beforehand
                      param_grid, # your parameter grid
                      cv=5, # the value for K in K-fold Cross Validation
                      scoring='accuracy', # the performance metric to use,
                      verbose=1) # we want informative outputs during the training process, try changing it to 2 and see what happens

search.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('columntransformer',
#                                         ColumnTransformer(transformers=[('pipeline-1',
#                                                                          Pipeline(steps=[('knnimputer',
#                                                                                           KNNImputer(n_neighbors=2)),
#                                                                                          ('minmaxscaler',
#                                                                                           MinMaxScaler())]),
#                                                                          ['LotArea',
#                                                                           'LotFrontage',
#                                                                           'TotalBsmtSF',
#                                                                           'BedroomAbvGr',
#                                                                           'Fireplaces',
#                                                                           'PoolArea',
#                                                                           'GarageCars',
#                                                                           'WoodDeckSF',
#                                                                           'ScreenPorch',
#                                                                           'MSSubClass',
#                                                                           'OverallQual',
#                                                                           'Ov...
#                                                                           'Condition1',
#                                                                           'Electrical',
#                                                                           'MasVnrType',
#                                                                           'RoofStyle',
#                                                                           'Heating',
#                                                                           'Condition2',
#                                                                           'Foundation'])])),
#                                        ('randomforestclassifier',
#                                         RandomForestClassifier(min_samples_leaf=2,
#                                                                min_samples_split=9,
#                                                                random_state=123))]),
#              param_grid={'randomforestclassifier__min_samples_leaf': range(2, 14, 2),
#                          'randomforestclassifier__min_samples_split': range(3, 12, 2)},
#              scoring='accuracy', verbose=1)

# %%
search.best_params_
# Out:
# {'randomforestclassifier__min_samples_leaf': 2,
#  'randomforestclassifier__min_samples_split': 3}

# %% [markdown]
# ## CrossValidate

# %%
cross_val_score(pipe, x_train, y_train, cv=5).mean()
# Out:
# np.float64(0.9528997468911632)

# %%
cross_val_score(pipe, x_test, y_test, cv=5).mean()
# Out:
# np.float64(0.9418468731735826)

# %% [markdown]
# ## Metric Scores

# %%
from sklearn.metrics import (
    accuracy_score,
    recall_score,
    precision_score,
    f1_score,
    balanced_accuracy_score,
    cohen_kappa_score
)

# Function to get the scores for our model(s)
def evaluate_model(model, X_test, y_test):
    y_pred = model.predict(X_test)
    scores = {
        "Accuracy": accuracy_score(y_test, y_pred),
        "Recall": recall_score(y_test, y_pred),
        "Precision": precision_score(y_test, y_pred),
        "Specificity": recall_score(y_test, y_pred, pos_label=0),
        "F1 Score": f1_score(y_test, y_pred),
        "Balanced Accuracy": balanced_accuracy_score(y_test, y_pred),
        "Cohen's Kappa": cohen_kappa_score(y_test, y_pred)
    }
    return scores

# Create an empty DataFrame to store model evaluation results
model_scores_df = pd.DataFrame(columns=[
    "Model", "Accuracy", "Recall", "Precision",
    "Specificity", "F1 Score", "Balanced Accuracy", "Cohen's Kappa"
])

# Evaluate the Decision Tree model
dt_scores = evaluate_model(search, x_test, y_test)
dt_scores["Model"] = "Decision Forest"

# Convert the dictionary to a Series matching the DataFrame columns, then assign as a new row
model_scores_df.loc[len(model_scores_df)] = pd.Series(dt_scores, index=model_scores_df.columns)

# Display the DataFrame
model_scores_df
# Out:
#              Model  Accuracy    Recall Precision Specificity  F1 Score  \
# 0  Decision Forest  0.945205  0.697674  0.909091    0.987952  0.789474
#
#   Balanced Accuracy Cohen's Kappa
# 0          0.842813      0.758603

# %% [markdown]
# ## Result

# %%
x_new = pd.read_csv("test.csv")

# %%
testing_data = x_new.set_index('Id')

# %%
testing_data["Expensive"] = search.predict(testing_data)

# %%
pred = testing_data[["Expensive"]]

# %%
pred.to_csv("Submission.csv")
